# %%
import numpy as np
import random
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator

X_train = np.loadtxt('input.csv', delimiter = ',')
Y_train = np.loadtxt('labels.csv',  delimiter = ',')

X_test = np.loadtxt('input_test.csv', delimiter  = ',')
Y_test = np.loadtxt('labels_test.csv', delimiter = ',')

# %%
X_train = X_train.reshape(len(X_train), 100, 100, 3)           
Y_train = Y_train.reshape(len(Y_train), 1)

X_test = X_test.reshape(len(X_test), 100, 100, 3)
Y_test = Y_test.reshape(len(Y_test), 1)

X_train = X_train/255.0
X_test = X_test/255.0

#Data augmentation to improve training
datagen = ImageDataGenerator(
    rotation_range = 20,
    width_shift_range = 0.2,
    height_shift_range = 0.2,
    horizontal_flip = True,
    zoom_range = 0.2
)

# %%
print("Shape of X_train:", X_train.shape)
print("Shape of Y_train:", Y_train.shape)
print("Shape of X_test:", X_test.shape)
print("Shape of Y_test:", Y_test.shape)
# Out:
# Shape of X_train: (2000, 100, 100, 3)
# Shape of Y_train: (2000, 1)
# Shape of X_test: (400, 100, 100, 3)
# Shape of Y_test: (400, 1)

# %%
idx = random.randint(0, len(X_train))
plt.imshow(X_train[idx, :])
plt.show()

# %%
model = Sequential([
    Conv2D(32, (3,3), activation = 'relu', input_shape = (100, 100, 3)),
    MaxPooling2D((2,2)),
    
    Conv2D(32, (3,3), activation = 'relu'),
    MaxPooling2D((2,2)),
    
    Flatten(),
    Dense(64, activation = 'relu'),
    Dense(1, activation = 'sigmoid')
])
# Out:
# C:\Users\prakh\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
idx = random.randint(0, len(X_train))
plt.imshow(X_train[idx, :])
plt.show()

# %%
model = Sequential()

model.add(Conv2D(32, (3,3), activation = 'relu', input_shape = (100, 100, 3)))
model.add(MaxPooling2D((2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3,3), activation = 'relu'))
model.add(MaxPooling2D((2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3,3), activation = 'relu'))
model.add(MaxPooling2D((2,2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(128, activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation = 'sigmoid'))

# %%
model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

# %%
model.fit(datagen.flow(X_train, Y_train, batch_size=32),
        epochs = 30,
        validation_data = (X_test, Y_test),
        verbose=1)
# Out:
# Epoch 1/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 16s 226ms/step - accuracy: 0.4910 - loss: 0.7249 - val_accuracy: 0.5550 - val_loss: 0.6929
# Epoch 2/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 12s 191ms/step - accuracy: 0.5185 - loss: 0.6925 - val_accuracy: 0.5000 - val_loss: 0.6835
# Epoch 3/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 13s 203ms/step - accuracy: 0.5225 - loss: 0.6936 - val_accuracy: 0.5625 - val_loss: 0.6908
# Epoch 4/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 11s 178ms/step - accuracy: 0.5060 - loss: 0.6920 - val_accuracy: 0.5125 - val_loss: 0.6777
# Epoch 5/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 13s 201ms/step - accuracy: 0.5715 - loss: 0.6796 - val_accuracy: 0.5975 - val_loss: 0.6520
# Epoch 6/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 12s 192ms/step - accuracy: 0.5610 - loss: 0.6731 - val_accuracy: 0.5225 - val_loss: 0.6819
# Epoch 7/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 12s 183ms/step - accuracy: 0.5285 - loss: 0.6834 - val_accuracy: 0.5875 - val_loss: 0.6713
# Epoch 8/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 12s 183ms/step - accuracy: 0.5795 - loss: 0.6730 - val_accuracy: 0.5900 - val_loss: 0.6544
# Epoch 9/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 12s 183ms/step - accuracy: 0.5925 - loss: 0.6693 - val_accuracy: 0.6625 - val_loss: 0.6392
# Epoch 10/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 12s 188ms/step - accuracy: 0.6065 - loss: 0.6567 - val_accuracy: 0.6650 - val_loss: 0.6369
# Epoch 11/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 12s 183ms/step - accuracy: 0.6140 - loss: 0.6530 - val_accuracy: 0.6575 - val_loss: 0.6321
# Epoch 12/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 12s 191ms/step - accuracy: 0.6340 - loss: 0.6423 - val_accuracy: 0.6900 - val_loss: 0.6178
# Epoch 13/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 12s 190ms/step - accuracy: 0.5710 - loss: 0.6802 - val_accuracy: 0.5625 - val_loss: 0.6659
# Epoch 14/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 12s 183ms/step - accuracy: 0.6135 - loss: 0.6513 - val_accuracy: 0.6900 - val_loss: 0.6314
# Epoch 15/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 12s 183ms/step - accuracy: 0.6505 - loss: 0.6297 - val_accuracy: 0.6575 - val_loss: 0.6233
# Epoch 16/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 16s 247ms/step - accuracy: 0.6310 - loss: 0.6462 - val_accuracy: 0.6925 - val_loss: 0.6049
# Epoch 17/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 12s 184ms/step - accuracy: 0.6655 - loss: 0.6239 - val_accuracy: 0.6525 - val_loss: 0.6250
# Epoch 18/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 11s 176ms/step - accuracy: 0.6660 - loss: 0.6122 - val_accuracy: 0.7400 - val_loss: 0.5537
# Epoch 19/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 11s 175ms/step - accuracy: 0.6765 - loss: 0.6100 - val_accuracy: 0.6975 - val_loss: 0.5674
# Epoch 20/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 11s 174ms/step - accuracy: 0.6700 - loss: 0.6046 - val_accuracy: 0.6625 - val_loss: 0.6141
# Epoch 21/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 11s 176ms/step - accuracy: 0.6825 - loss: 0.5955 - val_accuracy: 0.7675 - val_loss: 0.5300
# Epoch 22/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 13s 210ms/step - accuracy: 0.6705 - loss: 0.6057 - val_accuracy: 0.7500 - val_loss: 0.5714
# Epoch 23/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 262ms/step - accuracy: 0.6850 - loss: 0.5947 - val_accuracy: 0.7150 - val_loss: 0.5549
# Epoch 24/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 14s 221ms/step - accuracy: 0.6950 - loss: 0.5926 - val_accuracy: 0.7375 - val_loss: 0.5535
# Epoch 25/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 14s 225ms/step - accuracy: 0.7125 - loss: 0.5793 - val_accuracy: 0.7675 - val_loss: 0.5205
# Epoch 26/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 14s 224ms/step - accuracy: 0.7060 - loss: 0.5860 - val_accuracy: 0.7325 - val_loss: 0.5454
# Epoch 27/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 14s 221ms/step - accuracy: 0.6985 - loss: 0.5796 - val_accuracy: 0.7575 - val_loss: 0.5317
# Epoch 28/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 13s 208ms/step - accuracy: 0.6990 - loss: 0.5824 - val_accuracy: 0.7925 - val_loss: 0.5061
# Epoch 29/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 20s 206ms/step - accuracy: 0.6875 - loss: 0.5969 - val_accuracy: 0.7525 - val_loss: 0.5268
# Epoch 30/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 13s 205ms/step - accuracy: 0.6830 - loss: 0.5925 - val_accuracy: 0.7875 - val_loss: 0.5010

# %%
model.evaluate(X_test, Y_test)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.7875 - loss: 0.5010
# [0.5009787082672119, 0.7875000238418579]

# %%
idx2 = random.randint(0, len(Y_test))
plt.imshow(X_test[idx2, :])
plt.show()

y_pred = model.predict(X_test[idx2, :].reshape(1, 100, 100, 3))
y_pred = y_pred > 0.5

if(y_pred == 0):
    pred = 'dog'
else:
    pred = 'cat'
    
print("Our model says it is a :", pred)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# Our model says it is a : cat

# %%
model.save('model.h5')
print('Saved model to model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Saved model to model.h5
